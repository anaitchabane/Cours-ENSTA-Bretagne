# %% [markdown]
# # 1-Définition des matrices Q, K, V

# %%
import numpy as np

# Nous travaillons avec 3 tokens fictifs
tokens = ["t1", "t2", "t3"]
print("Tokens :", tokens)

# On définit des matrices Q, K, V simples à la main
# d_k = 2 pour que tout reste lisible
Q = np.array([
    [1.0, 0.0],  # Query pour t1
    [0.0, 1.0],  # Query pour t2
    [1.0, 1.0],  # Query pour t3
])

K = np.array([
    [1.0, 0.0],  # Key   pour t1
    [1.0, 1.0],  # Key   pour t2
    [0.0, 1.0],  # Key   pour t3
])

V = np.array([
    [1.0, 0.0],  # Value pour t1
    [0.0, 1.0],  # Value pour t2
    [1.0, 1.0],  # Value pour t3
])

print("Q =\n", Q)
print("\nK =\n", K)
print("\nV =\n", V)

d_k = Q.shape[1]
print("\nd_k =", d_k)
# Out:
# Tokens : ['t1', 't2', 't3']
# Q =
#  [[1. 0.]
#  [0. 1.]
#  [1. 1.]]
#
# K =
#  [[1. 0.]
#  [1. 1.]
#  [0. 1.]]
#
# V =
#  [[1. 0.]
#  [0. 1.]
#  [1. 1.]]
#
# d_k = 2

# %% [markdown]
# # 2. Scores bruts : S = Q K^T / sqrt(d_k)

# %%
S = Q @ K.T / np.sqrt(d_k)  # (3 x 3)
print("S = Q K^T / sqrt(d_k) :\n", np.round(S, 3))
# Out:
# S = Q K^T / sqrt(d_k) :
#  [[0.707 0.707 0.   ]
#  [0.    0.707 0.707]
#  [0.707 1.414 0.707]]

# %% [markdown]
# # 3. Softmax ligne par ligne

# %%
def softmax_rowwise(x):
    # x : matrice (n x m)
    # on applique softmax sur chaque ligne
    x_max = np.max(x, axis=1, keepdims=True)      # pour la stabilité numérique
    e = np.exp(x - x_max)
    return e / e.sum(axis=1, keepdims=True)

A = softmax_rowwise(S)
print("A = softmax_ligne_par_ligne(S) :\n", np.round(A, 3))

print("\nVérification (somme des lignes de A) :")
print(np.round(A.sum(axis=1), 3))
# Out:
# A = softmax_ligne_par_ligne(S) :
#  [[0.401 0.401 0.198]
#  [0.198 0.401 0.401]
#  [0.248 0.503 0.248]]
#
# Vérification (somme des lignes de A) :
# [1. 1. 1.]

# %% [markdown]
# # 4. Sortie de la self-attention : O = A V

# %%
O = A @ V  # (3 x 2)
print("O = A V :\n", np.round(O, 3))

for i, tok in enumerate(tokens):
    print(f"Représentation transformée pour {tok} :", np.round(O[i], 3))
# Out:
# O = A V :
#  [[0.599 0.599]
#  [0.599 0.802]
#  [0.497 0.752]]
# Représentation transformée pour t1 : [0.599 0.599]
# Représentation transformée pour t2 : [0.599 0.802]
# Représentation transformée pour t3 : [0.497 0.752]

# %%
import pandas as pd

df_S = pd.DataFrame(S, index=tokens, columns=tokens)
df_A = pd.DataFrame(A, index=tokens, columns=tokens)

print("Scores S :")
display(df_S.style.format("{:.3f}"))

print("Poids d'attention A :")
display(df_A.style.format("{:.3f}"))
# Out:
# Scores S :
# <style type="text/css">
# </style>
# <table id="T_8a3e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a3e3_level0_col0" class="col_heading level0 col0" >t1</th>
#       <th id="T_8a3e3_level0_col1" class="col_heading level0 col1" >t2</th>
#       <th id="T_8a3e3_level0_col2" class="col_heading level0 col2" >t3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a3e3_level0_row0" class="row_heading level0 row0" >t1</th>
#       <td id="T_8a3e3_row0_col0" class="data row0 col0" >0.707</td>
#       <td id="T_8a3e3_row0_col1" class="data row0 col1" >0.707</td>
#       <td id="T_8a3e3_row0_col2" class="data row0 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_8a3e3_level0_row1" class="row_heading level0 row1" >t2</th>
#       <td id="T_8a3e3_row1_col0" class="data row1 col0" >0.000</td>
#       <td id="T_8a3e3_row1_col1" class="data row1 col1" >0.707</td>
#       <td id="T_8a3e3_row1_col2" class="data row1 col2" >0.707</td>
#     </tr>
#     <tr>
#       <th id="T_8a3e3_level0_row2" class="row_heading level0 row2" >t3</th>
#       <td id="T_8a3e3_row2_col0" class="data row2 col0" >0.707</td>
#       <td id="T_8a3e3_row2_col1" class="data row2 col1" >1.414</td>
#       <td id="T_8a3e3_row2_col2" class="data row2 col2" >0.707</td>
#     </tr>
#   </tbody>
# </table>
# Poids d'attention A :
# <style type="text/css">
# </style>
# <table id="T_27dda">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27dda_level0_col0" class="col_heading level0 col0" >t1</th>
#       <th id="T_27dda_level0_col1" class="col_heading level0 col1" >t2</th>
#       <th id="T_27dda_level0_col2" class="col_heading level0 col2" >t3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27dda_level0_row0" class="row_heading level0 row0" >t1</th>
#       <td id="T_27dda_row0_col0" class="data row0 col0" >0.401</td>
#       <td id="T_27dda_row0_col1" class="data row0 col1" >0.401</td>
#       <td id="T_27dda_row0_col2" class="data row0 col2" >0.198</td>
#     </tr>
#     <tr>
#       <th id="T_27dda_level0_row1" class="row_heading level0 row1" >t2</th>
#       <td id="T_27dda_row1_col0" class="data row1 col0" >0.198</td>
#       <td id="T_27dda_row1_col1" class="data row1 col1" >0.401</td>
#       <td id="T_27dda_row1_col2" class="data row1 col2" >0.401</td>
#     </tr>
#     <tr>
#       <th id="T_27dda_level0_row2" class="row_heading level0 row2" >t3</th>
#       <td id="T_27dda_row2_col0" class="data row2 col0" >0.248</td>
#       <td id="T_27dda_row2_col1" class="data row2 col1" >0.503</td>
#       <td id="T_27dda_row2_col2" class="data row2 col2" >0.248</td>
#     </tr>
#   </tbody>
# </table>
